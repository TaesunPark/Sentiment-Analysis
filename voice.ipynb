# %%
from imutils import paths
from sklearn import preprocessing
import sklearn
import os
import librosa
from librosa import display

# %%
cd drive/MyDrive/sentiment\ analysis/Sentiment-Analysis/
# Out:
# /content/drive/MyDrive/sentiment analysis/Sentiment-Analysis

# %%
filepath = './Dataset/men/M_000002_상처.wav'

# %%
audio, sr = librosa.load(filepath, sr=16000)

# %%
print('sr:', sr, ', audio shape:', audio.shape)
print('length:', audio.shape[0]/float(sr), 'secs')
# Out:
# sr: 16000 , audio shape: (38417,)
# length: 2.4010625 secs

# %%
MFCCs = librosa.feature.mfcc(audio, sr=16000,n_mfcc=100, n_fft=400, hop_length=160)

# %%
MFCCs = sklearn.preprocessing.scale(MFCCs, axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "

# %%
pad2d = lambda a, i: a[:, 0:i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0], i-a.shape[1]))))
padded_mfcc = pad2d(MFCCs, 240)

# %%
MFCCs.shape
# Out:
# (100, 241)

# %%
padded_mfcc.shape
# Out:
# (100, 240)

# %%
librosa.display.specshow(padded_mfcc, sr=16000, x_axis='time')
